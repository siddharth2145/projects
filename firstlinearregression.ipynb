# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
df.isnull().mean()*100
# Out:
# cgpa       0.0
# package    0.0
# dtype: float64

# %%
X=df.iloc[:,0:1]

# %%
y=df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2,test_size=0.2)

# %%
X_train.head()
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77

# %%
from sklearn.linear_model import LinearRegression

# %%
df.sample(100)
# Out:
#      cgpa  package
# 61   5.48     1.61
# 131  6.37     2.01
# 184  7.88     3.14
# 20   7.28     3.16
# 95   6.63     2.79
# ..    ...      ...
# 8    6.09     2.31
# 57   6.60     1.94
# 54   6.86     3.09
# 195  6.93     2.46
# 186  7.84     3.47
#
# [100 rows x 2 columns]

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[3].values.reshape(1,1))
# Out:
# C:\Users\ASUs\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.57434935])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel("CGPA")
plt.ylabel("package")
# Out:
# Text(0, 0.5, 'package')
